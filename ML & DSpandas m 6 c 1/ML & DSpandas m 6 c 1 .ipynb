# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
# df = pd.read_csv("D:/D.S & M.L/Resource/2025-08-10T16-17-43.226Z-Class 11 - Pandas Data Manipulation Basics.csv")

# %%
df

# %%
print(df)

# %%
df.head()

# %%
df.tail()

# %%
df.head(20)

# %%
df[["Name"]]

# %%
df[["Name", "Sex", "Age"]]

# %%
df[df['Age']>60]
