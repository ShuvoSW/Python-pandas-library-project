# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['Pandy', 'Bamboo', 'Fuzzy'],
    'Age': [5, 7, 4],
    'Bamboo_sticks' : [15, 6, 6]
}
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Name  Age  Bamboo_sticks
# 0   Pandy    5             15
# 1  Bamboo    7              6
# 2   Fuzzy    4              6

# %%
df.head()
