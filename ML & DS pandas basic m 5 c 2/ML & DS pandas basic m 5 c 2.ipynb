# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['Pandy', 'Bamboo', 'Fuzzy'],
    'Age': [5, 7, 4],
    'Bamboo_sticks' : [15, 6, 6]
}
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Name  Age  Bamboo_sticks
# 0   Pandy    5             15
# 1  Bamboo    7              6
# 2   Fuzzy    4              6

# %%
df.head()
# Out:
#      Name  Age  Bamboo_sticks
# 0   Pandy    5             15
# 1  Bamboo    7              6
# 2   Fuzzy    4              6

# %%
df[df['Age']<6]   # df e filtering , filtering on a colums with a logic # df =df[df['Age']<6]
# Out:
#     Name  Age  Bamboo_sticks
# 0  Pandy    5             15
# 2  Fuzzy    4              6

# %%
df['Job'] = ['Intern', 'Manger', 'Intern']  #np.nan
print(df)
# Out:
#      Name  Age  Bamboo_sticks     Job
# 0   Pandy    5             15  Intern
# 1  Bamboo    7              6  Manger
# 2   Fuzzy    4              6  Intern

# %%
df.loc[df['Name']=='Pandy', 'Age'] = 6

# %%
df
# Out:
#      Name  Age  Bamboo_sticks     Job
# 0   Pandy    6             15  Intern
# 1  Bamboo    7              6  Manger
# 2   Fuzzy    4              6  Intern

# %%
df = df.drop('Bamboo_sticks', axis=1)

# %%
df
# Out:
#      Name  Age     Job
# 0   Pandy    6  Intern
# 1  Bamboo    7  Manger
# 2   Fuzzy    4  Intern

# %%
df = df.drop(['Age','Job' ], axis=1)

# %%
df
# Out:
#      Name
# 0   Pandy
# 1  Bamboo
# 2   Fuzzy

# %%
df.iloc[:3] #row [0]
# Out:
#      Name
# 0   Pandy
# 1  Bamboo
# 2   Fuzzy

# %%
df['Age']
# Out:
# 0    5
# 1    7
# 2    4
# Name: Age, dtype: int64

# %%
df.iloc[0:2, 0:2]
# Out:
#      Name
# 0   Pandy
# 1  Bamboo

# %%
df.iloc[0:2, 1:3]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
df = pd.DataFrame({
    'Name': ['Pandy', 'Bamboo', 'Fuzzy', 'Fluffy'],
    'Age': [5,7,4,6],
    'Bamboo_Stickes': [33,55,66,77]
},index = ['a','b','c','d'])

# %%
df
# Out:
#      Name  Age  Bamboo_Stickes
# a   Pandy    5              33
# b  Bamboo    7              55
# c   Fuzzy    4              66
# d  Fluffy    6              77

# %%
df.loc['b']
# Out:
# Name              Bamboo
# Age                    7
# Bamboo_Stickes        55
# Name: b, dtype: object

# %%
df.loc[['a','c'], ['Name', 'Age']]
# Out:
#     Name  Age
# a  Pandy    5
# c  Fuzzy    4

# %%
df_json = pd.read_json('test.json' )

# %%
df_json.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406

# %%
df_json.tail()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df_json.shape
# Out:
# (6, 4)

# %%
df_json.to_csv("Converted to csv.csv",index=False)

# %%
df_csv = pd.read_csv("Converted to csv.csv")

# %%
df_csv
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df_csv.drop('Calories',axis=1)
# Out:
#    Duration  Pulse  Maxpulse
# 0        60    110       130
# 1        60    117       145
# 2        60    103       135
# 3        45    109       175
# 4        45    117       148
# 5        60    102       127

# %%
df_csv
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df_csv.to_excel("output.xlsx", index=False)

# %%
df_csv[['Duration', 'Pulse']]
# Out:
#    Duration  Pulse
# 0        60    110
# 1        60    117
# 2        60    103
# 3        45    109
# 4        45    117
# 5        60    102

# %%
df_csv[(df_csv['Duration']>50) & (df_csv['Pulse']>105)]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479

# %%
left = pd.DataFrame({
    'ID': [1,2,3],
    'Name' : ['Pandy', 'Fuzzy', 'Bamboo']
})
right = pd.DataFrame({
    'ID': [1,2,4],
    'hoby' : ['Climbing', 'Sleeping', 'Eating']
})
merge_df = pd.merge(left,right, on='ID', how='left')
print(merge_df)
# Out:
#    ID    Name      hoby
# 0   1   Pandy  Climbing
# 1   2   Fuzzy  Sleeping
# 2   3  Bamboo       NaN

# %%
condatenated_df = pd.concat([left,right], ignore_index=True)
condatenated_df
# Out:
#    ID    Name      hoby
# 0   1   Pandy       NaN
# 1   2   Fuzzy       NaN
# 2   3  Bamboo       NaN
# 3   1     NaN  Climbing
# 4   2     NaN  Sleeping
# 5   4     NaN    Eating

# %%
condatenated_df = pd.concat([left,right], axis=1)

# %%
condatenated_df
# Out:
#    ID    Name  ID      hoby
# 0   1   Pandy   1  Climbing
# 1   2   Fuzzy   2  Sleeping
# 2   3  Bamboo   4    Eating
